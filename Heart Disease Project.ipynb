# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\dell\Downloads\heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
#checking for null values
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#concise summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#plotting histograms for all numeric values
df.hist(bins=50, grid=False, figsize=(20,15));

# %%
#plotting histograms for all numeric values
df.hist(bins=50, grid=True, figsize=(20,15));

# %%
#plotting histograms for all numeric values ,if I took for 100 
df.hist(bins=100, grid=False, figsize=(20,15));

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
questions=["1. How many people have heart disease or how many people who don't have?",
          "2. People of which sex has been seen more heart disease?",
          "3. People of which age are suffering more from heart diseases?",
          "4. How many peoples of which sex who don't have heart disease?",
          "5. People of which sex are more suffering more from chest pain?",
          "6. How many people with chest pain are most pron to have heart disease?"]

# %%
questions
# Out:
# ["1. How many people have heart disease or how many people who don't have?",
#  '2. People of which sex has been seen more heart disease?',
#  '3. People of which age are suffering more from heart diseases?',
#  "4. How many peoples of which sex who don't have heart disease?",
#  '5. People of which sex are more suffering more from chest pain?',
#  '6. How many people with chest pain are most pron to have heart disease?']

# %%
df.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df.target.value_counts().plot(kind="bar",color=["pink","purple"])
plt.title("Heart disease values")
plt.xlabel("1= Heart disease, 0=No Heart disease")
plt.ylabel("Amount");

# %%
df.target.value_counts().plot(kind="pie",figsize=(8,6))
plt.legend(["Disease","No Disease"]);

# %%
df.sex.value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
df.sex.value_counts().plot(kind="pie",figsize=(8,6))
plt.title("Male Female Ratio")
plt.legend(["Male","Female"]);

# %%
df.age.value_counts()
# Out:
# 58    68
# 57    57
# 54    53
# 59    46
# 52    43
# 51    39
# 56    39
# 62    37
# 60    37
# 44    36
# 64    34
# 41    32
# 63    32
# 67    31
# 61    31
# 55    30
# 65    27
# 43    26
# 42    26
# 53    26
# 66    25
# 45    25
# 48    23
# 46    23
# 50    21
# 47    18
# 49    17
# 35    15
# 39    14
# 70    14
# 68    12
# 38    12
# 71    11
# 40    11
# 69     9
# 37     6
# 34     6
# 29     4
# 76     3
# 77     3
# 74     3
# Name: age, dtype: int64

# %%
pd.crosstab(df.target, df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
sns.countplot(x="target",data=df,hue="sex")
plt.title("Heart disease frequency")
plt.xlabel("0= No heart disease,1= heart disease");

# %%
df.cp.value_counts()
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %%
df.cp.value_counts().plot(kind="bar", color=["pink","green","blue","aqua"])
plt.title("Chest pain type vs count");

# %%
pd.crosstab(df.sex, df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(df.sex,df.cp).plot(kind="bar", color=["pink","olive","orange","aqua"])
plt.title("Chest pain type");
plt.xlabel("0=Female, 1=Male");

# %%
pd.crosstab(df.cp, df.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x="cp",data=df,hue="target");

# %%
sns.displot(x="age",data=df,bins=30,kde=True);

# %%
sns.displot(x="age",data=df,bins=30,kde=False);

# %%
#displot for distribution
sns.displot(x="age",data=df,bins=50,kde=True);

# %%
sns.displot(x="sex",data=df,bins=30,kde=True);

# %%
sns.displot(x="thalach",data=df,bins=30,kde=True,color="aqua");
