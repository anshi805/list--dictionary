# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\householdtask3.csv")
df
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
df.head()
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# 2   2.3   16747        21145       13402    14408
# 3   2.8   31308        29855       18917    18266
# 4   3.0   49106        46561       26870    24672

# %%
df.tail()
# Out:
#     year  tot_hhs     own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 65  2020   352564  213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182  235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328  288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588  156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013  314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# 65   2.8   69779        57351       38889    33468
# 66   3.0   88944        83038       48929    45978
# 67   2.6  104277       123424       62718    71985
# 68   3.2   69581        54141       35075    29684
# 69   1.7   34712        34643       25077    27037

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         70 non-null     int64
#  1   tot_hhs      70 non-null     int64
#  2   own          70 non-null     int64
#  3   own_wm       70 non-null     int64
#  4   own_prop     70 non-null     float64
#  5   own_wm_prop  70 non-null     float64
#  6   prop_hhs     70 non-null     float64
#  7   age          70 non-null     float64
#  8   size         70 non-null     float64
#  9   income       70 non-null     int64
#  10  expenditure  70 non-null     int64
#  11  eqv_income   70 non-null     int64
#  12  eqv_exp      70 non-null     int64
# dtypes: float64(5), int64(8)
# memory usage: 7.2 KB

# %%
df.describe()
# Out:
#               year       tot_hhs           own         own_wm   own_prop  \
# count    70.000000  7.000000e+01  7.000000e+01      70.000000  70.000000
# mean   2014.000000  4.125193e+05  2.689711e+05  129639.457143  63.505714
# std       4.273274  3.491547e+05  2.385230e+05  128627.124758  15.145257
# min    2008.000000  1.322150e+05  3.008000e+04   14220.000000  22.800000
# 25%    2011.000000  3.123460e+05  1.838408e+05   50636.750000  55.400000
# 50%    2014.000000  3.276340e+05  2.153065e+05  107909.000000  64.200000
# 75%    2017.000000  3.468958e+05  2.604148e+05  147563.000000  73.675000
# max    2020.000000  1.756740e+06  1.125000e+06  574662.000000  88.100000
#
#        own_wm_prop    prop_hhs        age       size         income  \
# count    70.000000   70.000000  70.000000  70.000000      70.000000
# mean     30.348571   24.985714  38.284286   2.625714   56694.785714
# std      14.010004   21.102368   9.376345   0.350439   28921.315551
# ...

# %%
x_column = 'year'  
y_column = 'tot_hhs'

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='skyblue')
plt.xlabel('YEAR')  
plt.ylabel('TOT_HHS')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'own'

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='orange')
plt.xlabel('YEAR')  
plt.ylabel('OWN')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'own_wm'

# %%
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='PURPLE')
plt.xlabel('YEAR')  
plt.ylabel('OWN_WM')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'own_prop'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='olive')
plt.xlabel('YEAR') 
plt.ylabel('OWN_PROP')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'own_wm_prop'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='grey')
plt.xlabel('YEAR') 
plt.ylabel('OWN_WM_PROP')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'prop_hhs'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='red')
plt.xlabel('YEAR') 
plt.ylabel('PROP_HHS')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'age'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='yellow')
plt.xlabel('YEAR') 
plt.ylabel('AGE')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'size'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='pink')
plt.xlabel('YEAR') 
plt.ylabel('SIZE')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'expenditure'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='magenta')
plt.xlabel('YEAR') 
plt.ylabel('EXPENDITURE')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'income'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='brown')
plt.xlabel('YEAR') 
plt.ylabel('INCOME')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'eqv_income'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='black')
plt.xlabel('YEAR') 
plt.ylabel('EQV_INCOME')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'eqv_exp'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='green')
plt.xlabel('YEAR') 
plt.ylabel('EQV_EXP')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'age'  
y_column = 'income'
plt.figure(figsize=(10, 6))
plt.bar(df[x_column], df[y_column], color='brown')
plt.xlabel('AGE') 
plt.ylabel('INCOME')  
plt.title('Bar Chart Title')  
plt.legend(['Legend Label'])  
plt.show()

# %%
x_column = 'year'  
y_column = 'tot_hhs'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='blue')
plt.xlabel('YEAR')
plt.ylabel('TOT_HHS')
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'own'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='indigo')
plt.xlabel('YEAR')
plt.ylabel('OWN')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'own_wm'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='YELLOW')
plt.xlabel('YEAR')
plt.ylabel('OWN_WM')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'own_prop'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='pink')
plt.xlabel('YEAR')
plt.ylabel('OWN_PROP')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'own_wm_prop'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='red')
plt.xlabel('YEAR')
plt.ylabel('OWN_WM_PROP')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'age'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='green')
plt.xlabel('YEAR')
plt.ylabel('AGE')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'size'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='turquoise')
plt.xlabel('YEAR')
plt.ylabel('SIZE')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'expenditure'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='maroon')
plt.xlabel('YEAR')
plt.ylabel('EXPENDITURE')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'income'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='teal')
plt.xlabel('YEAR')
plt.ylabel('INCOME')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'eqv_income'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='cyan')
plt.xlabel('YEAR')
plt.ylabel('EQV_INCOME')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'year'  
y_column = 'eqv_exp'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='tan')
plt.xlabel('YEAR')
plt.ylabel('EQV_EXP')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'income'  
y_column = 'own'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='indigo')
plt.xlabel('INCOME')
plt.ylabel('OWN')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'income'  
y_column = 'age'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='orange')
plt.xlabel('INCOME')
plt.ylabel('AGE')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()

# %%
x_column = 'income'  
y_column = 'expenditure'
plt.figure(figsize=(10, 6))
plt.plot(df[x_column], df[y_column], marker='o', linestyle='-', color='grey')
plt.xlabel('INCOME')
plt.ylabel('EXPENDITURE')  
plt.title('Line Chart Title')  
plt.legend(['Legend Label'])   
plt.show()
